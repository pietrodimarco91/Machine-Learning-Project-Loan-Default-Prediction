# %%
import imp
imp.reload(utils)
import pandas as pd
import numpy as np
import monster
imp.reload(monster)
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
#from xgboost import XGBClassifier

RANDOM_SEED = 23423

params_rf = {
	'n_estimators' : [100, 120],
	'min_samples_leaf' : [4, 5, 6],
	'min_samples_split' : [13, 15, 19],
	'n_jobs' : [-1],
	'random_state' : [RANDOM_SEED]
}

params_xgb = {
	'base_score' : [0.3],
	'max_depth' : [3, 10, 50],
	'n_estimators' : [100, 200],
	'seed' : [RANDOM_SEED],
	'nthread' : [2]
}

params_ada = {
	'n_estimators' : [50, 70, 100],
	'learning_rate' : [1.0, 0.9, 1.1],
	'random_state' : [RANDOM_SEED]
}

params_mlp = {
	'hidden_layer_sizes' : [(100,), (120,), (100,20)],
	'random_state' : [RANDOM_SEED],
	'early_stopping' : [True]
}


train = pd.read_csv('data/train_all_features.csv')

print train.info()

train['LIMIT_BAL_SQUARE'] = train.apply(lambda x : x['LIMIT_BAL']*x['LIMIT_BAL'], axis=1)

print train['LIMIT_BAL_SQUARE'].describe()

X = train.drop(['CUST_COD', 'DEFAULT PAYMENT JAN'], axis=1)
y = train['DEFAULT PAYMENT JAN']


models = [RandomForestClassifier, AdaBoostClassifier, MLPClassifier]
params = [params_rf, params_ada, params_mlp]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26884 entries, 0 to 26883
# Data columns (total 83 columns):
# CUST_COD                     26884 non-null float64
# LIMIT_BAL                    26884 non-null float64
# SEX                          26884 non-null float64
# PAY_DEC                      26884 non-null float64
# PAY_NOV                      26884 non-null float64
# PAY_OCT                      26884 non-null float64
# PAY_SEP                      26884 non-null float64
# PAY_AUG                      26884 non-null float64
# PAY_JUL                      26884 non-null float64
# BILL_AMT_DEC                 26884 non-null float64
# BILL_AMT_NOV                 26884 non-null float64
# BILL_AMT_OCT                 26884 non-null float64
# BILL_AMT_SEP                 26884 non-null float64
# BILL_AMT_AUG                 26884 non-null float64
# BILL_AMT_JUL                 26884 non-null float64
# PAY_AMT_DEC                  26884 non-null float64
# ...

# %%
mst = monster.Monster(models, params, random_state = RANDOM_SEED)
mst.fit(X, y)

f = open('models_out.pydat', 'wb')
pickle.dump(mst, f)
f.close()
# Out:
# Converting X in numpy array
# Converting y in numpy array
# Created test holdout. % positive class in test holdout = 0.221127022503
#
#
# ========== Starting grid search for <class 'sklearn.ensemble.forest.RandomForestClassifier'> ==========
# Evaluating model with parameters: {'min_samples_split': 13, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 23423, 'min_samples_leaf': 4}
# Training fold #1	0.566037735849
# Training fold #2	0.50773993808
# Training fold #3	0.52772073922
# Training fold #4	0.509920634921
# Training fold #5	0.541001064963
# Training fold #6	0.549180327869
# Training fold #7	0.561933534743
# Training fold #8	0.54042988741
# Training fold #9	0.564729867482
# Training fold #10	0.505376344086
# Average score: 0.537407007462     Average threshold: 0.310739855111
# Evaluating model with parameters: {'min_samples_split': 13, 'n_estimators': 120, 'n_jobs': -1, 'random_state': 23423, 'min_samples_leaf': 4}
# Training fold #1	0.569055036345
# ...
